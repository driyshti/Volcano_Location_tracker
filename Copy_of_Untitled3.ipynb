# %%
import numpy as np
import pandas as pd
import folium as fo
data = pd.read_csv("https://raw.githubusercontent.com/amankharwal/Website-data/master/Volcano.csv")
print(data.head())
# Out:
#    Year  Month   Day  TSU   EQ                    Name              Location  \
# 0  2010      1   NaN  NaN  NaN              Tungurahua               Ecuador
# 1  2010      3  31.0  NaN  NaN        Eyjafjallajokull             Iceland-S
# 2  2010      5  27.0  NaN  NaN                  Pacaya             Guatemala
# 3  2010      5  29.0  TSU   EQ                 Sarigan  Mariana Is-C Pacific
# 4  2010      8   6.0  NaN  NaN  Karangetang [Api Siau]  Sangihe Is-Indonesia
#
#          Country  Latitude  Longitude  ...  TOTAL_DEATHS  \
# 0        Ecuador    -1.467    -78.442  ...           NaN
# 1        Iceland    63.630    -19.620  ...           2.0
# 2      Guatemala    14.381    -90.601  ...           1.0
# 3  United States    16.708    145.780  ...           NaN
# 4      Indonesia     2.780    125.480  ...           4.0
#
#   TOTAL_DEATHS_DESCRIPTION TOTAL_MISSING TOTAL_MISSING_DESCRIPTION  \
# 0                      NaN           NaN                       NaN
# 1                      1.0           NaN                       NaN
# 2                      1.0           3.0                       1.0
# 3                      NaN           NaN                       NaN
# 4                      1.0           NaN                       NaN
#
#    TOTAL_INJURIES TOTAL_INJURIES_DESCRIPTION  TOTAL_DAMAGE_MILLIONS_DOLLARS  \
# 0             NaN                        NaN                            NaN
# 1             NaN                        NaN                            NaN
# 2             NaN                        NaN                            NaN
# 3             NaN                        NaN                            NaN
# 4             5.0                        1.0                            NaN
#
#    TOTAL_DAMAGE_DESCRIPTION  TOTAL_HOUSES_DESTROYED  \
# 0                       1.0                     NaN
# 1                       NaN                     NaN
# 2                       1.0                     3.0
# 3                       NaN                     NaN
# 4                       NaN                     NaN
#
#    TOTAL_HOUSES_DESTROYED_DESCRIPTION
# 0                                 NaN
# 1                                 NaN
# 2                                 1.0
# 3                                 NaN
# 4                                 1.0
#
# [5 rows x 36 columns]

# %%
lat = list(data["Latitude"])
lon = list(data["Longitude"])
name = list(data["Name"])

volcano = fo.FeatureGroup(name="Volcano")
for a, b, c in zip(lat, lon, name):
  volcano.add_child(fo.Marker(location=[a, b], popup=c, icon=fo.Icon(color='blue')))

fo.Map().add_child(volcano)
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_d6b9067e9a38c696aa4c345d6fd13cac {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_d6b9067e9a38c696aa4c345d6fd13cac&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_d6b9067e9a38c696aa4c345d6fd13cac = L.map(
#                 &quot;map_d6b9067e9a38c696aa4c345d6fd13cac&quot;,
#                 {
#                     center: [0, 0],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 1,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_f95cd2a57a05897aa91189942628715e = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_d6b9067e9a38c696aa4c345d6fd13cac);
#
#
#             var feature_group_3b29cb6c3c1ed533bd72ce44618e6112 = L.featureGroup(
#                 {}
#             ).addTo(map_d6b9067e9a38c696aa4c345d6fd13cac);
#
#
#             var marker_bbfd78a00654db6350d1d6460f08c157 = L.marker(
#                 [-1.467, -78.442],
#                 {}
#             ).addTo(feature_group_3b29cb6c3c1ed533bd72ce44618e6112);
#
#
#             var icon_bfd78f4a0750acfb33355473bd23bc1f = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;blue&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_bbfd78a00654db6350d1d6460f08c157.setIcon(icon_bfd78f4a0750acfb33355473bd23bc1f);
#
#
#         var popup_df65b427c01f9508b50909a247a4c2ad = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_8755aac710bacc710dae256928f63125 = $(`&lt;div id=&quot;html_8755aac710bacc710dae256928f63125&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Tungurahua&lt;/div&gt;`)[0];
#                 popup_df65b427c01f9508b50909a247a4c2ad.setContent(html_8755aac710bacc710dae256928f63125);
#
#
#
#         marker_bbfd78a00654db6350d1d6460f08c157.bindPopup(popup_df65b427c01f9508b50909a247a4c2ad)
#         ;
#
#
#
#
#             var marker_73eadc6bdf52dba5311dd62d6af6bdec = L.marker(
#                 [63.63, -19.62],
#                 {}
#             ).addTo(feature_group_3b29cb6c3c1ed533bd72ce44618e6112);
#
#
#             var icon_72f8ff05f8965a778c636ec8be59c11b = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;blue&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_73eadc6bdf52dba5311dd62d6af6bdec.setIcon(icon_72f8ff05f8965a778c636ec8be59c11b);
#
#
#         var popup_e071ba4a21ec4e2dc6310e5b3f363eae = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_cca6bf1098a3c5658af37fb2107fc88e = $(`&lt;div id=&quot;html_cca6bf1098a3c5658af37fb2107fc88e&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Eyjafjallajokull&lt;/div&gt;`)[0];
#                 popup_e071ba4a21ec4e2dc6310e5b3f363eae.setContent(html_cca6bf1098a3c5658af37fb2107fc88e);
#
#
#
#         marker_73eadc6bdf52dba5311dd62d6af6bdec.bindPopup(popup_e071ba4a21ec4e2dc6310e5b3f363eae)
#         ;
#
#
#
#
#             var marker_ed61b19f0651230f4ff9dd12a6aa5ec0 = L.marker(
#                 [14.381, -90.601],
#                 {}
#             ).addTo(feature_group_3b29cb6c3c1ed533bd72ce44618e6112);
#
#
#             var icon_b211cd19f56ec890f9a9c3085194720e = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;blue&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_ed61b19f0651230f4ff9dd12a6aa5ec0.setIcon(icon_b211cd19f56ec890f9a9c3085194720e);
#
#
#         var popup_8f23b0a1ee286a0758844c7891b4d46a = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_78b27f57c8ac83a9fc521b3cf86202b0 = $(`&lt;div id=&quot;html_78b27f57c8ac83a9fc521b3cf86202b0&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Pacaya&lt;/div&gt;`)[0];
#                 popup_8f23b0a1ee286a0758844c7891b4d46a.setContent(html_78b27f57c8ac83a9fc521b3cf86202b0);
#
#
#
#         marker_ed61b19f0651230f4ff9dd12a6aa5ec0.bindPopup(popup_8f23b0a1ee286a0758844c7891b4d46a)
#         ;
#
#
#
#
#             var marker_48f57fd5c3363cdd3439798bd3ccaf12 = L.marker(
#                 [16.708, 145.78],
#                 {}
#             ).addTo(feature_group_3b29cb6c3c1ed533bd72ce44618e6112);
